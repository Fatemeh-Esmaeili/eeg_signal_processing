# %%
# Cell 1: Import dependencies
import os
import glob
import logging
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import mne
import json
from pathlib import Path
import warnings
warnings.filterwarnings('ignore')

# Cell 2: Copy and paste the ENTIRE EEGFilteringPipeline class here
# ↓↓↓ COPY THE ENTIRE CLASS CODE FROM ABOVE HERE ↓↓↓

class EEGFilteringPipeline:
    def __init__(self, base_path, output_dir="processed_eeg"):
        # ... [paste the complete class code]
    
    # ... [paste all the methods]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 root_path="PEEG"
#       3 output_directory="filtered_EEG"
# ----> 4 pipeline = EEGFilteringPipeline(root_path, output_directory)
#       5 pipeline.run_pipeline()
#       7 # Custom filtering parameters
#
# NameError: name 'EEGFilteringPipeline' is not defined
